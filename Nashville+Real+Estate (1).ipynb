# %%
import pandas as pd
import numpy as np
df_housing = pd.read_csv('datasets/Nashville_housing_data_2013_2016.csv')

# %%
df_housing['Land Use'].unique()
# Out:
# array(['RESIDENTIAL CONDO', 'SINGLE FAMILY', 'VACANT RES LAND', 'DUPLEX',
#        'CONDO', 'ZERO LOT LINE', 'RESIDENTIAL COMBO/MISC', 'TRIPLEX',
#        'CHURCH', 'QUADPLEX', 'VACANT COMMERCIAL LAND',
#        'CONDOMINIUM OFC  OR OTHER COM CONDO', 'STRIP SHOPPING CENTER',
#        'VACANT RURAL LAND', 'DORMITORY/BOARDING HOUSE', 'MOBILE HOME',
#        'PARSONAGE', 'SPLIT CLASS', 'GREENBELT',
#        'VACANT ZONED MULTI FAMILY', 'PARKING LOT',
#        'OFFICE BLDG (ONE OR TWO STORIES)', 'VACANT RESIDENTIAL LAND',
#        'RESTURANT/CAFETERIA', 'FOREST', 'CONVENIENCE MARKET WITHOUT GAS',
#        'CLUB/UNION HALL/LODGE', 'LIGHT MANUFACTURING',
#        'ONE STORY GENERAL RETAIL STORE', 'DAY CARE CENTER',
#        'GREENBELT/RES\nGRRENBELT/RES',
#        'APARTMENT: LOW RISE (BUILT SINCE 1960)', 'VACANT RESIENTIAL LAND',
#        'SMALL SERVICE SHOP', 'TERMINAL/DISTRIBUTION WAREHOUSE',
#        'NON-PROFIT CHARITABLE SERVICE',
# ...

# %%
df_housing.groupby('Land Use').count()
# Out:
#                                             Unnamed: 0  Unnamed: 0.1  \
# Land Use
# APARTMENT: LOW RISE (BUILT SINCE 1960)               2             2
# CHURCH                                              34            34
# CLUB/UNION HALL/LODGE                                1             1
# CONDO                                              252           252
# CONDOMINIUM OFC  OR OTHER COM CONDO                 35            35
# CONVENIENCE MARKET WITHOUT GAS                       1             1
# DAY CARE CENTER                                      2             2
# DORMITORY/BOARDING HOUSE                            19            19
# DUPLEX                                            1389          1389
# FOREST                                              10            10
# GREENBELT                                           10            10
# GREENBELT/RES\nGRRENBELT/RES                         3             3
# ...

# %%
list(df_housing)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'Parcel ID',
#  'Land Use',
#  'Property Address',
#  'Suite/ Condo   #',
#  'Property City',
#  'Sale Date',
#  'Sale Price',
#  'Legal Reference',
#  'Sold As Vacant',
#  'Multiple Parcels Involved in Sale',
#  'Owner Name',
#  'Address',
#  'City',
#  'State',
#  'Acreage',
#  'Tax District',
#  'Neighborhood',
#  'image',
#  'Land Value',
#  'Building Value',
#  'Total Value',
#  'Finished Area',
#  'Foundation Type',
#  'Year Built',
#  'Exterior Wall',
#  'Grade',
#  'Bedrooms',
#  'Full Bath',
#  'Half Bath']

# %%
df1 = df_housing.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Parcel ID','State', 'City', 'Legal Reference', 'image', 'Tax District', 'Sold As Vacant', 'Suite/ Condo   #', 'Property City', 'Multiple Parcels Involved in Sale', 'Owner Name', 'Address'], axis = 1)
df1.head()
# Out:
#             Land Use   Property Address   Sale Date  Sale Price  Acreage  \
# 0  RESIDENTIAL CONDO    1208  3RD AVE S  2013-01-24      132000      NaN
# 1      SINGLE FAMILY   1802  STEWART PL  2013-01-11      191500     0.17
# 2      SINGLE FAMILY  2761  ROSEDALE PL  2013-01-18      202000     0.11
# 3      SINGLE FAMILY  224  PEACHTREE ST  2013-01-18       32000     0.17
# 4      SINGLE FAMILY      316  LUTIE ST  2013-01-23      102000     0.34
#
#    Neighborhood  Land Value  Building Value  Total Value  Finished Area  \
# 0           NaN         NaN             NaN          NaN            NaN
# 1        3127.0     32000.0        134400.0     168300.0     1149.00000
# 2        9126.0     34000.0        157800.0     191800.0     2090.82495
# 3        3130.0     25000.0        243700.0     268700.0     2145.60001
# 4        3130.0     25000.0        138100.0     164800.0     1969.00000
#
#   Foundation Type  Year Built Exterior Wall Grade  Bedrooms  Full Bath  \
# ...

# %%
df1.groupby('Land Use').count()
# Out:
#                                             Property Address  Sale Date  \
# Land Use
# APARTMENT: LOW RISE (BUILT SINCE 1960)                     2          2
# CHURCH                                                    34         34
# CLUB/UNION HALL/LODGE                                      1          1
# CONDO                                                    247        252
# CONDOMINIUM OFC  OR OTHER COM CONDO                       35         35
# CONVENIENCE MARKET WITHOUT GAS                             1          1
# DAY CARE CENTER                                            2          2
# DORMITORY/BOARDING HOUSE                                  19         19
# DUPLEX                                                  1373       1389
# FOREST                                                    10         10
# GREENBELT                                                 10         10
# GREENBELT/RES\nGRRENBELT/RES                               3          3
# ...

# %%
df1.groupby('Land Use').count()
# Out:
#                                             Property Address  Sale Date  \
# Land Use
# APARTMENT: LOW RISE (BUILT SINCE 1960)                     2          2
# CHURCH                                                    34         34
# CLUB/UNION HALL/LODGE                                      1          1
# CONDO                                                    247        252
# CONDOMINIUM OFC  OR OTHER COM CONDO                       35         35
# CONVENIENCE MARKET WITHOUT GAS                             1          1
# DAY CARE CENTER                                            2          2
# DORMITORY/BOARDING HOUSE                                  19         19
# DUPLEX                                                  1373       1389
# FOREST                                                    10         10
# GREENBELT                                                 10         10
# GREENBELT/RES\nGRRENBELT/RES                               3          3
# ...

# %%
def classifier(x):
    residence = ['RESIDENTIAL CONDO', 'SINGLE FAMILY', 'APARTMENT: LOW RISE (BUILT SINCE 1960)','DUPLEX',
       'CONDO', 'ZERO LOT LINE', 'RESIDENTIAL COMBO/MISC', 'TRIPLEX','QUADPLEX',
                'DORMITORY/BOARDING HOUSE', 'MOBILE HOME', 'PARSONAGE']
    
    commerical = ['SMALL SERVICE SHOP', 'TERMINAL/DISTRIBUTION WAREHOUSE',
       'NON-PROFIT CHARITABLE SERVICE',
       'METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK', 'NIGHTCLUB/LOUNGE',
       'MORTUARY/CEMETERY', 'PARKING LOT','OFFICE BLDG (ONE OR TWO STORIES)', 
        'CLUB/UNION HALL/LODGE', 'LIGHT MANUFACTURING',
       'ONE STORY GENERAL RETAIL STORE', 'DAY CARE CENTER','CHURCH', 'RESTURANT/CAFETERIA', 'CONVENIENCE MARKET WITHOUT GAS']
    
    vacant = ['VACANT RES LAND', 'VACANT COMMERCIAL LAND', 'VACANT RURAL LAND','VACANT ZONED MULTI FAMILY', 
              'VACANT RESIDENTIAL LAND','VACANT RESIENTIAL LAND']
    
    other = ['GREENBELT','GREENBELT/RES\nGRRENBELT/RES']
    if x in residence:
        return 'Residence'
    elif x in commerical:
        return 'Commerical'
    elif x in vacant:
        return 'Vacant'
    else:
        return 'Other'

# %%
df1['Category'] = df1['Land Use'].apply(classifier)

# %%
df1.head()
# Out:
#             Land Use   Property Address   Sale Date  Sale Price  Acreage  \
# 0  RESIDENTIAL CONDO    1208  3RD AVE S  2013-01-24      132000      NaN
# 1      SINGLE FAMILY   1802  STEWART PL  2013-01-11      191500     0.17
# 2      SINGLE FAMILY  2761  ROSEDALE PL  2013-01-18      202000     0.11
# 3      SINGLE FAMILY  224  PEACHTREE ST  2013-01-18       32000     0.17
# 4      SINGLE FAMILY      316  LUTIE ST  2013-01-23      102000     0.34
#
#    Neighborhood  Land Value  Building Value  Total Value  Finished Area  \
# 0           NaN         NaN             NaN          NaN            NaN
# 1        3127.0     32000.0        134400.0     168300.0     1149.00000
# 2        9126.0     34000.0        157800.0     191800.0     2090.82495
# 3        3130.0     25000.0        243700.0     268700.0     2145.60001
# 4        3130.0     25000.0        138100.0     164800.0     1969.00000
#
#   Foundation Type  Year Built Exterior Wall Grade  Bedrooms  Full Bath  \
# ...

# %%
list(df1)
# Out:
# ['Land Use',
#  'Property Address',
#  'Sale Date',
#  'Sale Price',
#  'Acreage',
#  'Neighborhood',
#  'Land Value',
#  'Building Value',
#  'Total Value',
#  'Finished Area',
#  'Foundation Type',
#  'Year Built',
#  'Exterior Wall',
#  'Grade',
#  'Bedrooms',
#  'Full Bath',
#  'Half Bath',
#  'Category']

# %%
df1[['Category', 'Land Use',
 'Property Address',
 'Sale Date',
 'Sale Price',
 'Acreage',
 'Neighborhood',
 'Land Value',
 'Building Value',
 'Total Value',
 'Finished Area',
 'Foundation Type',
 'Year Built',
 'Exterior Wall',
 'Grade',
 'Bedrooms',
 'Full Bath',
 'Half Bath',
 'Category']]
# Out:
#         Category                             Land Use  \
# 0      Residence                    RESIDENTIAL CONDO
# 1      Residence                        SINGLE FAMILY
# 2      Residence                        SINGLE FAMILY
# 3      Residence                        SINGLE FAMILY
# 4      Residence                        SINGLE FAMILY
# 5      Residence                        SINGLE FAMILY
# 6      Residence                    RESIDENTIAL CONDO
# 7      Residence                        SINGLE FAMILY
# 8      Residence                        SINGLE FAMILY
# 9      Residence                        SINGLE FAMILY
# 10     Residence                        SINGLE FAMILY
# 11     Residence                        SINGLE FAMILY
# 12     Residence                        SINGLE FAMILY
# 13        Vacant                      VACANT RES LAND
# 14     Residence                        SINGLE FAMILY
# 15     Residence                        SINGLE FAMILY
# ...

# %%
df1.groupby('Category').count()
# Out:
#             Land Use  Property Address  Sale Date  Sale Price  Acreage  \
# Category
# Commerical        63                63         63          63       58
# Other             76                76         76          76       39
# Residence      51312             51218      51312       51312    24214
# Vacant          5185              5120       5185        5185     1706
#
#             Neighborhood  Land Value  Building Value  Total Value  \
# Category
# Commerical            58          58              58           58
# Other                 39          39              39           39
# Residence          24214       24214           24214        24214
# Vacant              1706        1706            1706         1706
#
#             Finished Area  Foundation Type  Year Built  Exterior Wall  Grade  \
# Category
# Commerical             44               44          44             44     44
# Other                  22               22          22             22     22
# ...

# %%
df1.corr()['Sale Price']
# Out:
# Sale Price        1.000000
# Acreage           0.201185
# Neighborhood      0.057126
# Land Value        0.603653
# Building Value    0.574624
# Total Value       0.661740
# Finished Area     0.634628
# Year Built        0.037270
# Bedrooms          0.372739
# Full Bath         0.512608
# Half Bath         0.239271
# Name: Sale Price, dtype: float64

# %%
df1['Difference_in_price'] = df1['Sale Price'] - df1['Total Value']

# %%
df1.head()
# Out:
#             Land Use   Property Address   Sale Date  Sale Price  Acreage  \
# 0  RESIDENTIAL CONDO    1208  3RD AVE S  2013-01-24      132000      NaN
# 1      SINGLE FAMILY   1802  STEWART PL  2013-01-11      191500     0.17
# 2      SINGLE FAMILY  2761  ROSEDALE PL  2013-01-18      202000     0.11
# 3      SINGLE FAMILY  224  PEACHTREE ST  2013-01-18       32000     0.17
# 4      SINGLE FAMILY      316  LUTIE ST  2013-01-23      102000     0.34
#
#    Neighborhood  Land Value  Building Value  Total Value  Finished Area  \
# 0           NaN         NaN             NaN          NaN            NaN
# 1        3127.0     32000.0        134400.0     168300.0     1149.00000
# 2        9126.0     34000.0        157800.0     191800.0     2090.82495
# 3        3130.0     25000.0        243700.0     268700.0     2145.60001
# 4        3130.0     25000.0        138100.0     164800.0     1969.00000
#
#   Foundation Type  Year Built Exterior Wall Grade  Bedrooms  Full Bath  \
# ...

# %%
df1[['Category',  'Land Use',
 'Property Address',
 'Sale Date',
 'Sale Price','Difference_in_price',
 'Acreage',
 'Neighborhood',
 'Land Value',
 'Building Value',
 'Total Value',
 'Finished Area',
 'Foundation Type',
 'Year Built',
 'Exterior Wall',
 'Grade',
 'Bedrooms',
 'Full Bath',
 'Half Bath',
 'Category']]
# Out:
#         Category                             Land Use  \
# 0      Residence                    RESIDENTIAL CONDO
# 1      Residence                        SINGLE FAMILY
# 2      Residence                        SINGLE FAMILY
# 3      Residence                        SINGLE FAMILY
# 4      Residence                        SINGLE FAMILY
# 5      Residence                        SINGLE FAMILY
# 6      Residence                    RESIDENTIAL CONDO
# 7      Residence                        SINGLE FAMILY
# 8      Residence                        SINGLE FAMILY
# 9      Residence                        SINGLE FAMILY
# 10     Residence                        SINGLE FAMILY
# 11     Residence                        SINGLE FAMILY
# 12     Residence                        SINGLE FAMILY
# 13        Vacant                      VACANT RES LAND
# 14     Residence                        SINGLE FAMILY
# 15     Residence                        SINGLE FAMILY
# ...

# %%
df1['Difference_in_price'].mean()
# Out:
# 48328.91978321866

# %%
df1['Difference_in_price'].max()
# Out:
# 12300000.0

# %%
df1[df1['Difference_in_price'] == 12300000.0 ]
# Out:
#                       Land Use     Property Address   Sale Date  Sale Price  \
# 20136  VACANT RESIDENTIAL LAND  2812  MCGAVOCK PIKE  2014-08-15    12350000
#
#        Acreage  Neighborhood  Land Value  Building Value  Total Value  \
# 20136      3.0        4126.0     50000.0             0.0      50000.0
#
#        Finished Area Foundation Type  Year Built Exterior Wall Grade  \
# 20136            NaN             NaN         NaN           NaN   NaN
#
#        Bedrooms  Full Bath  Half Bath Category  Difference_in_price
# 20136       NaN        NaN        NaN   Vacant           12300000.0

# %%
df1['Difference_in_price'].min()
# Out:
# -5497600.0

# %%
df1[df1['Difference_in_price'] == -5497600.0 ]
# Out:
#            Land Use     Property Address   Sale Date  Sale Price  Acreage  \
# 9674  SINGLE FAMILY  4225  FRANKLIN PIKE  2013-11-15      905000      4.0
#
#       Neighborhood  Land Value  Building Value  Total Value  Finished Area  \
# 9674        9527.0    520000.0       5824300.0    6402600.0        15446.0
#
#      Foundation Type  Year Built Exterior Wall Grade  Bedrooms  Full Bath  \
# 9674           CRAWL      2016.0         STONE  X          5.0        5.0
#
#       Half Bath   Category  Difference_in_price
# 9674        2.0  Residence           -5497600.0

# %%
df_residence = df1[df1['Category'] == 'Residence']

# %%
df_residence.count()
# Out:
# Land Use               51312
# Property Address       51218
# Sale Date              51312
# Sale Price             51312
# Acreage                24214
# Neighborhood           24214
# Land Value             24214
# Building Value         24214
# Total Value            24214
# Finished Area          23599
# Foundation Type        23597
# Year Built             23598
# Exterior Wall          23598
# Grade                  23598
# Bedrooms               23595
# Full Bath              23598
# Half Bath              23488
# Category               51312
# Difference_in_price    24214
# dtype: int64

# %%
df_residence_new = df_residence.dropna()

# %%
df_residence_new.count()
# Out:
# Land Use               23480
# Property Address       23480
# Sale Date              23480
# Sale Price             23480
# Acreage                23480
# Neighborhood           23480
# Land Value             23480
# Building Value         23480
# Total Value            23480
# Finished Area          23480
# Foundation Type        23480
# Year Built             23480
# Exterior Wall          23480
# Grade                  23480
# Bedrooms               23480
# Full Bath              23480
# Half Bath              23480
# Category               23480
# Difference_in_price    23480
# dtype: int64

# %%
df_residence_new.corr()['Sale Price']
# Out:
# Sale Price             1.000000
# Acreage                0.335466
# Neighborhood           0.080435
# Land Value             0.750579
# Building Value         0.754591
# Total Value            0.831435
# Finished Area          0.725029
# Year Built             0.050361
# Bedrooms               0.384734
# Full Bath              0.565033
# Half Bath              0.259205
# Difference_in_price    0.486251
# Name: Sale Price, dtype: float64

# %%
df_residence.corr()['Sale Price']
# Out:
# Sale Price             1.000000
# Acreage                0.325804
# Neighborhood           0.080315
# Land Value             0.746740
# Building Value         0.731753
# Total Value            0.818959
# Finished Area          0.723331
# Year Built             0.050203
# Bedrooms               0.384421
# Full Bath              0.563870
# Half Bath              0.259114
# Difference_in_price    0.501785
# Name: Sale Price, dtype: float64

# %%
df_commerical = df1[df1['Category'] == 'Commerical']

# %%
df_commerical.count()
# Out:
# Land Use               63
# Property Address       63
# Sale Date              63
# Sale Price             63
# Acreage                58
# Neighborhood           58
# Land Value             58
# Building Value         58
# Total Value            58
# Finished Area          44
# Foundation Type        44
# Year Built             44
# Exterior Wall          44
# Grade                  44
# Bedrooms               36
# Full Bath              44
# Half Bath              44
# Category               63
# Difference_in_price    58
# dtype: int64

# %%
df_commerical_new = df_commerical.dropna()

# %%
df_commerical_new.count()
# Out:
# Land Use               36
# Property Address       36
# Sale Date              36
# Sale Price             36
# Acreage                36
# Neighborhood           36
# Land Value             36
# Building Value         36
# Total Value            36
# Finished Area          36
# Foundation Type        36
# Year Built             36
# Exterior Wall          36
# Grade                  36
# Bedrooms               36
# Full Bath              36
# Half Bath              36
# Category               36
# Difference_in_price    36
# dtype: int64

# %%
df_commerical_new.corr()['Sale Price']
# Out:
# Sale Price             1.000000
# Acreage                0.448802
# Neighborhood           0.122474
# Land Value             0.407727
# Building Value         0.438497
# Total Value            0.608025
# Finished Area          0.181427
# Year Built            -0.062451
# Bedrooms              -0.119797
# Full Bath             -0.044391
# Half Bath              0.441709
# Difference_in_price    0.937154
# Name: Sale Price, dtype: float64

# %%
df_commerical.corr()['Sale Price']
# Out:
# Sale Price             1.000000
# Acreage                0.717431
# Neighborhood           0.040462
# Land Value             0.416129
# Building Value         0.762636
# Total Value            0.771316
# Finished Area          0.949402
# Year Built             0.086186
# Bedrooms              -0.119797
# Full Bath             -0.119922
# Half Bath              0.083675
# Difference_in_price    0.467093
# Name: Sale Price, dtype: float64

# %%
df1[df1['Category'] == 'Other']
# Out:
#                                   Land Use         Property Address  \
# 3396   CONDOMINIUM OFC  OR OTHER COM CONDO          2115  YEAMAN PL
# 3397   CONDOMINIUM OFC  OR OTHER COM CONDO             505  MAIN ST
# 3398                 STRIP SHOPPING CENTER     700 A  FATHERLAND ST
# 7525                           SPLIT CLASS         293  CATHY JO DR
# 8406                             GREENBELT          208  BENZING RD
# 8407                             GREENBELT            0  BENZING RD
# 8673   CONDOMINIUM OFC  OR OTHER COM CONDO         2905  12TH AVE S
# 8674   CONDOMINIUM OFC  OR OTHER COM CONDO         2905  12TH AVE S
# 9060                           SPLIT CLASS         1521  RUSSELL ST
# 9258                           SPLIT CLASS      1300  RURAL HILL RD
# 10781                          SPLIT CLASS       3123  BRICKDALE LN
# 10836                            GREENBELT          1833  HUDSON RD
# 10837                            GREENBELT          1829  HUDSON RD
# ...

# %%
#df_other = df1[df1['Category'] == 'Other']
#df_other['Land Use'].unique()
# Out:
# array(['CONDOMINIUM OFC  OR OTHER COM CONDO', 'STRIP SHOPPING CENTER',
#        'SPLIT CLASS', 'GREENBELT', 'FOREST', 'GREENBELT/RES\nGRRENBELT/RES'], dtype=object)

# %%
# Move 'RESTURANT/CAFETERIA', 'CONVENIENCE MARKET WITHOUT GAS' to commerical
